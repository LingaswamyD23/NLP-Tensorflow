# %% [markdown]
# # CHAT_BOT_Using_DeepLearning-Tensorflow

# %% [markdown]
# # Importing pacakages

# %%
import numpy as np
import nltk
# nltk.download('punkt')
from nltk.stem.porter import PorterStemmer

import random
import json

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import layers

# %% [markdown]
# # Preprocessing of Data

# %%
stemmer = PorterStemmer()

def tokenize(sentence):
    return nltk.word_tokenize(sentence)


def stem(word):
    return stemmer.stem(word.lower())


def bag_of_words(tokenized_sentence, words):
    # stem each word
    sentence_words = [stem(word) for word in tokenized_sentence]
    # initialize bag with 0 for each word
    bag = np.zeros(len(words), dtype=np.float32)
    for idx, w in enumerate(words):
        if w in sentence_words: 
            bag[idx] = 1

    return bag


with open('../Dataset.json', 'r') as f:
    dataset = json.load(f)

all_words = []
tags = []
xy = []
# loop through each sentence in our intents patterns
for conv in dataset['conversations']:
    tag = conv['header']
    # add to tag list
    tags.append(tag)
    for pattern in conv['start']:
        # tokenize each word in the sentence
        w = tokenize(pattern)
        # add to our words list
        all_words.extend(w)
        # add to xy pair
        xy.append((w, tag))

# stem and lower each word
ignore_words = ['?', '.', '!']
all_words = [stem(w) for w in all_words if w not in ignore_words]
# remove duplicates and sort
all_words = sorted(set(all_words))
tags = sorted(set(tags))

# create training data
X_train = []
y_train = []
for (pattern_sentence, tag) in xy:
    # X: bag of words for each pattern_sentence
    bag = bag_of_words(pattern_sentence, all_words)
    X_train.append(bag)
    # y: PyTorch CrossEntropyLoss needs only class labels, not one-hot
    label = tags.index(tag)
    y_train.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)

#convertion of normal data to categorical values
y_train = tf. keras.utils.to_categorical(y_train, 7)

# %% [markdown]
# # Model

# %%
#model
input_size = len(X_train[0])

def myModel():
    inp = Input(shape=input_size)
    x = Dense(units=8, activation='relu')(inp)
    x = Dense(units=8, activation='relu')(x)
    x = Dense(units=8, activation='relu')(x)
    out = Dense(units=7, activation= tf.keras.activations.softmax)(x)
    
    return Model(inputs = inp, outputs = out, name = 'MY_Model')


model = myModel()
model.summary()
# Out:
# Model: "MY_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 54)]              0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 440
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 63
# =================================================================
# Total params: 647
# Trainable params: 647
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Prepare the training dataset.

# %%
batch_size = 8

# Prepare the training dataset.
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %% [markdown]
# # Training Step

# %%
epochs = 200
learning_rate = 0.001

# Instantiate an optimizer.
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# Instantiate a loss function.
loss_fn = tf.keras.losses.CategoricalCrossentropy()

for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))
    
    # Iterate over the batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            logits = model(x_batch_train, training=True)
            loss_value = loss_fn(y_batch_train, logits)

        grads = tape.gradient(loss_value, model.trainable_weights)
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        
        if epoch or epoch==0:
            print (f'Epoch [{epoch+1}/{epochs}], step : {step} Loss: {loss_value:.4f}')

print(f'final loss: {loss_value:.4f}')
# Out:
# Start of epoch 0
# Epoch [1/200], step : 0 Loss: 1.9890
# Epoch [1/200], step : 1 Loss: 2.0030
# Epoch [1/200], step : 2 Loss: 1.8943
# Epoch [1/200], step : 3 Loss: 1.9312
#
# Start of epoch 1
# Epoch [2/200], step : 0 Loss: 2.0283
# Epoch [2/200], step : 1 Loss: 1.8361
# Epoch [2/200], step : 2 Loss: 1.8955
# Epoch [2/200], step : 3 Loss: 2.2972
#
# Start of epoch 2
# Epoch [3/200], step : 0 Loss: 1.8848
# Epoch [3/200], step : 1 Loss: 1.9484
# Epoch [3/200], step : 2 Loss: 1.9802
# Epoch [3/200], step : 3 Loss: 1.9599
#
# Start of epoch 3
# Epoch [4/200], step : 0 Loss: 1.8804
# Epoch [4/200], step : 1 Loss: 1.9167
# Epoch [4/200], step : 2 Loss: 2.0128
# Epoch [4/200], step : 3 Loss: 1.8738
#
# Start of epoch 4
# Epoch [5/200], step : 0 Loss: 1.8818
# Epoch [5/200], step : 1 Loss: 1.9948
# Epoch [5/200], step : 2 Loss: 1.9136
# Epoch [5/200], step : 3 Loss: 1.8662
#
# Start of epoch 5
# Epoch [6/200], step : 0 Loss: 1.8830
# Epoch [6/200], step : 1 Loss: 1.8552
# Epoch [6/200], step : 2 Loss: 2.0110
# Epoch [6/200], step : 3 Loss: 1.9297
#
# Start of epoch 6
# Epoch [7/200], step : 0 Loss: 2.0007
# Epoch [7/200], step : 1 Loss: 1.9160
# Epoch [7/200], step : 2 Loss: 1.8550
# Epoch [7/200], step : 3 Loss: 1.7589
#
# Start of epoch 7
# Epoch [8/200], step : 0 Loss: 1.9641
# Epoch [8/200], step : 1 Loss: 1.8800
# Epoch [8/200], step : 2 Loss: 1.8652
# Epoch [8/200], step : 3 Loss: 1.9237
#
# Start of epoch 8
# Epoch [9/200], step : 0 Loss: 1.8410
# Epoch [9/200], step : 1 Loss: 1.8984
# Epoch [9/200], step : 2 Loss: 1.9440
# Epoch [9/200], step : 3 Loss: 1.9421
#
# Start of epoch 9
# Epoch [10/200], step : 0 Loss: 1.8937
# Epoch [10/200], step : 1 Loss: 1.8482
# Epoch [10/200], step : 2 Loss: 1.9015
# Epoch [10/200], step : 3 Loss: 2.0206
#
# Start of epoch 10
# Epoch [11/200], step : 0 Loss: 1.8508
# Epoch [11/200], step : 1 Loss: 1.9342
# Epoch [11/200], step : 2 Loss: 1.8129
# Epoch [11/200], step : 3 Loss: 2.1264
#
# Start of epoch 11
# Epoch [12/200], step : 0 Loss: 1.8224
# Epoch [12/200], step : 1 Loss: 2.0030
# Epoch [12/200], step : 2 Loss: 1.8268
# Epoch [12/200], step : 3 Loss: 1.8314
#
# Start of epoch 12
# Epoch [13/200], step : 0 Loss: 1.9025
# Epoch [13/200], step : 1 Loss: 1.9051
# Epoch [13/200], step : 2 Loss: 1.8019
# Epoch [13/200], step : 3 Loss: 1.9116
#
# Start of epoch 13
# Epoch [14/200], step : 0 Loss: 1.8801
# Epoch [14/200], step : 1 Loss: 1.8868
# Epoch [14/200], step : 2 Loss: 1.8393
# Epoch [14/200], step : 3 Loss: 1.8458
#
# Start of epoch 14
# Epoch [15/200], step : 0 Loss: 1.7945
# Epoch [15/200], step : 1 Loss: 1.9407
# Epoch [15/200], step : 2 Loss: 1.8518
# Epoch [15/200], step : 3 Loss: 1.8291
#
# Start of epoch 15
# Epoch [16/200], step : 0 Loss: 1.8065
# Epoch [16/200], step : 1 Loss: 1.9231
# Epoch [16/200], step : 2 Loss: 1.8443
# Epoch [16/200], step : 3 Loss: 1.7923
#
# Start of epoch 16
# Epoch [17/200], step : 0 Loss: 1.8406
# Epoch [17/200], step : 1 Loss: 1.8289
# Epoch [17/200], step : 2 Loss: 1.8531
# Epoch [17/200], step : 3 Loss: 1.9039
#
# Start of epoch 17
# Epoch [18/200], step : 0 Loss: 1.9263
# Epoch [18/200], step : 1 Loss: 1.8067
# Epoch [18/200], step : 2 Loss: 1.7928
# Epoch [18/200], step : 3 Loss: 1.7935
#
# Start of epoch 18
# Epoch [19/200], step : 0 Loss: 1.7819
# Epoch [19/200], step : 1 Loss: 1.8069
# Epoch [19/200], step : 2 Loss: 1.9224
# Epoch [19/200], step : 3 Loss: 1.7616
#
# Start of epoch 19
# Epoch [20/200], step : 0 Loss: 1.8903
# Epoch [20/200], step : 1 Loss: 1.8091
# Epoch [20/200], step : 2 Loss: 1.8237
# Epoch [20/200], step : 3 Loss: 1.6107
#
# Start of epoch 20
# Epoch [21/200], step : 0 Loss: 1.8214
# Epoch [21/200], step : 1 Loss: 1.7887
# Epoch [21/200], step : 2 Loss: 1.8248
# Epoch [21/200], step : 3 Loss: 1.8696
#
# Start of epoch 21
# Epoch [22/200], step : 0 Loss: 1.7544
# Epoch [22/200], step : 1 Loss: 1.8793
# Epoch [22/200], step : 2 Loss: 1.7786
# Epoch [22/200], step : 3 Loss: 1.8550
#
# Start of epoch 22
# Epoch [23/200], step : 0 Loss: 1.8687
# Epoch [23/200], step : 1 Loss: 1.7742
# Epoch [23/200], step : 2 Loss: 1.7612
# Epoch [23/200], step : 3 Loss: 1.7821
#
# Start of epoch 23
# Epoch [24/200], step : 0 Loss: 1.8362
# Epoch [24/200], step : 1 Loss: 1.7267
# Epoch [24/200], step : 2 Loss: 1.7836
# Epoch [24/200], step : 3 Loss: 1.9075
#
# Start of epoch 24
# Epoch [25/200], step : 0 Loss: 1.8053
# Epoch [25/200], step : 1 Loss: 1.7941
# Epoch [25/200], step : 2 Loss: 1.7101
# Epoch [25/200], step : 3 Loss: 1.9446
#
# Start of epoch 25
# Epoch [26/200], step : 0 Loss: 1.7578
# Epoch [26/200], step : 1 Loss: 1.8110
# Epoch [26/200], step : 2 Loss: 1.7633
# Epoch [26/200], step : 3 Loss: 1.7438
#
# Start of epoch 26
# Epoch [27/200], step : 0 Loss: 1.9108
# Epoch [27/200], step : 1 Loss: 1.6620
# Epoch [27/200], step : 2 Loss: 1.7271
# Epoch [27/200], step : 3 Loss: 1.7476
#
# Start of epoch 27
# Epoch [28/200], step : 0 Loss: 1.8757
# Epoch [28/200], step : 1 Loss: 1.7389
# Epoch [28/200], step : 2 Loss: 1.6878
# Epoch [28/200], step : 3 Loss: 1.6139
#
# Start of epoch 28
# Epoch [29/200], step : 0 Loss: 1.8802
# Epoch [29/200], step : 1 Loss: 1.6951
# Epoch [29/200], step : 2 Loss: 1.6340
# Epoch [29/200], step : 3 Loss: 1.8620
#
# Start of epoch 29
# Epoch [30/200], step : 0 Loss: 1.6655
# Epoch [30/200], step : 1 Loss: 1.8379
# Epoch [30/200], step : 2 Loss: 1.7599
# Epoch [30/200], step : 3 Loss: 1.5120
#
# Start of epoch 30
# Epoch [31/200], step : 0 Loss: 1.5990
# Epoch [31/200], step : 1 Loss: 1.9059
# Epoch [31/200], step : 2 Loss: 1.6889
# Epoch [31/200], step : 3 Loss: 1.6495
#
# Start of epoch 31
# Epoch [32/200], step : 0 Loss: 1.7641
# Epoch [32/200], step : 1 Loss: 1.6907
# Epoch [32/200], step : 2 Loss: 1.6936
# Epoch [32/200], step : 3 Loss: 1.6803
#
# Start of epoch 32
# Epoch [33/200], step : 0 Loss: 1.6644
# Epoch [33/200], step : 1 Loss: 1.6816
# Epoch [33/200], step : 2 Loss: 1.7893
# Epoch [33/200], step : 3 Loss: 1.5861
#
# Start of epoch 33
# Epoch [34/200], step : 0 Loss: 1.6636
# Epoch [34/200], step : 1 Loss: 1.5898
# Epoch [34/200], step : 2 Loss: 1.8146
# Epoch [34/200], step : 3 Loss: 1.7033
#
# Start of epoch 34
# Epoch [35/200], step : 0 Loss: 1.5895
# Epoch [35/200], step : 1 Loss: 1.5869
# Epoch [35/200], step : 2 Loss: 1.8603
# Epoch [35/200], step : 3 Loss: 1.6690
#
# Start of epoch 35
# Epoch [36/200], step : 0 Loss: 1.8508
# Epoch [36/200], step : 1 Loss: 1.7208
# Epoch [36/200], step : 2 Loss: 1.4993
# Epoch [36/200], step : 3 Loss: 1.3555
#
# Start of epoch 36
# Epoch [37/200], step : 0 Loss: 1.7073
# Epoch [37/200], step : 1 Loss: 1.5859
# Epoch [37/200], step : 2 Loss: 1.5431
# Epoch [37/200], step : 3 Loss: 2.1276
#
# Start of epoch 37
# Epoch [38/200], step : 0 Loss: 1.6885
# Epoch [38/200], step : 1 Loss: 1.5462
# Epoch [38/200], step : 2 Loss: 1.6971
# Epoch [38/200], step : 3 Loss: 1.5693
#
# Start of epoch 38
# Epoch [39/200], step : 0 Loss: 1.7213
# Epoch [39/200], step : 1 Loss: 1.6062
# Epoch [39/200], step : 2 Loss: 1.6169
# Epoch [39/200], step : 3 Loss: 1.3445
#
# Start of epoch 39
# Epoch [40/200], step : 0 Loss: 1.6229
# Epoch [40/200], step : 1 Loss: 1.6013
# Epoch [40/200], step : 2 Loss: 1.6179
# Epoch [40/200], step : 3 Loss: 1.5631
#
# Start of epoch 40
# Epoch [41/200], step : 0 Loss: 1.4858
# Epoch [41/200], step : 1 Loss: 1.6833
# Epoch [41/200], step : 2 Loss: 1.6310
# Epoch [41/200], step : 3 Loss: 1.5350
#
# Start of epoch 41
# Epoch [42/200], step : 0 Loss: 1.6157
# Epoch [42/200], step : 1 Loss: 1.6120
# Epoch [42/200], step : 2 Loss: 1.5267
# Epoch [42/200], step : 3 Loss: 1.5174
#
# Start of epoch 42
# Epoch [43/200], step : 0 Loss: 1.5618
# Epoch [43/200], step : 1 Loss: 1.6239
# Epoch [43/200], step : 2 Loss: 1.5677
# Epoch [43/200], step : 3 Loss: 1.3116
#
# Start of epoch 43
# Epoch [44/200], step : 0 Loss: 1.6224
# Epoch [44/200], step : 1 Loss: 1.3134
# Epoch [44/200], step : 2 Loss: 1.6331
# Epoch [44/200], step : 3 Loss: 1.8620
#
# Start of epoch 44
# Epoch [45/200], step : 0 Loss: 1.6470
# Epoch [45/200], step : 1 Loss: 1.4952
# Epoch [45/200], step : 2 Loss: 1.4639
# Epoch [45/200], step : 3 Loss: 1.4971
#
# Start of epoch 45
# Epoch [46/200], step : 0 Loss: 1.6281
# Epoch [46/200], step : 1 Loss: 1.4439
# Epoch [46/200], step : 2 Loss: 1.4970
# Epoch [46/200], step : 3 Loss: 1.4228
#
# Start of epoch 46
# Epoch [47/200], step : 0 Loss: 1.6520
# Epoch [47/200], step : 1 Loss: 1.5449
# Epoch [47/200], step : 2 Loss: 1.3709
# Epoch [47/200], step : 3 Loss: 1.2027
#
# Start of epoch 47
# Epoch [48/200], step : 0 Loss: 1.4602
# Epoch [48/200], step : 1 Loss: 1.5156
# Epoch [48/200], step : 2 Loss: 1.4005
# Epoch [48/200], step : 3 Loss: 1.7387
#
# Start of epoch 48
# Epoch [49/200], step : 0 Loss: 1.5716
# Epoch [49/200], step : 1 Loss: 1.4412
# Epoch [49/200], step : 2 Loss: 1.3985
# Epoch [49/200], step : 3 Loss: 1.3568
#
# Start of epoch 49
# Epoch [50/200], step : 0 Loss: 1.2863
# Epoch [50/200], step : 1 Loss: 1.3104
# Epoch [50/200], step : 2 Loss: 1.6577
# Epoch [50/200], step : 3 Loss: 1.7443
#
# Start of epoch 50
# Epoch [51/200], step : 0 Loss: 1.2649
# Epoch [51/200], step : 1 Loss: 1.5681
# Epoch [51/200], step : 2 Loss: 1.4409
# Epoch [51/200], step : 3 Loss: 1.4306
#
# Start of epoch 51
# Epoch [52/200], step : 0 Loss: 1.4590
# Epoch [52/200], step : 1 Loss: 1.4659
# Epoch [52/200], step : 2 Loss: 1.3465
# Epoch [52/200], step : 3 Loss: 1.1877
#
# Start of epoch 52
# Epoch [53/200], step : 0 Loss: 1.2439
# Epoch [53/200], step : 1 Loss: 1.4585
# Epoch [53/200], step : 2 Loss: 1.4597
# Epoch [53/200], step : 3 Loss: 1.3726
#
# Start of epoch 53
# Epoch [54/200], step : 0 Loss: 1.2220
# Epoch [54/200], step : 1 Loss: 1.3925
# Epoch [54/200], step : 2 Loss: 1.4157
# Epoch [54/200], step : 3 Loss: 1.6432
#
# Start of epoch 54
# Epoch [55/200], step : 0 Loss: 1.5232
# Epoch [55/200], step : 1 Loss: 1.1329
# Epoch [55/200], step : 2 Loss: 1.4263
# Epoch [55/200], step : 3 Loss: 1.1688
#
# Start of epoch 55
# Epoch [56/200], step : 0 Loss: 1.4427
# Epoch [56/200], step : 1 Loss: 1.1427
# Epoch [56/200], step : 2 Loss: 1.2961
# Epoch [56/200], step : 3 Loss: 1.7097
#
# Start of epoch 56
# Epoch [57/200], step : 0 Loss: 1.2559
# Epoch [57/200], step : 1 Loss: 1.5635
# Epoch [57/200], step : 2 Loss: 1.1094
# Epoch [57/200], step : 3 Loss: 1.2557
#
# Start of epoch 57
# Epoch [58/200], step : 0 Loss: 1.1644
# Epoch [58/200], step : 1 Loss: 1.2359
# Epoch [58/200], step : 2 Loss: 1.3659
# Epoch [58/200], step : 3 Loss: 1.6329
#
# Start of epoch 58
# Epoch [59/200], step : 0 Loss: 1.1735
# Epoch [59/200], step : 1 Loss: 1.3890
# Epoch [59/200], step : 2 Loss: 1.2565
# Epoch [59/200], step : 3 Loss: 1.1664
#
# Start of epoch 59
# Epoch [60/200], step : 0 Loss: 1.1839
# Epoch [60/200], step : 1 Loss: 1.3785
# Epoch [60/200], step : 2 Loss: 1.2299
# Epoch [60/200], step : 3 Loss: 0.9786
#
# Start of epoch 60
# Epoch [61/200], step : 0 Loss: 1.0771
# Epoch [61/200], step : 1 Loss: 1.2345
# Epoch [61/200], step : 2 Loss: 1.2668
# Epoch [61/200], step : 3 Loss: 1.5709
#
# Start of epoch 61
# Epoch [62/200], step : 0 Loss: 1.0431
# Epoch [62/200], step : 1 Loss: 1.1746
# Epoch [62/200], step : 2 Loss: 1.3904
# Epoch [62/200], step : 3 Loss: 1.1858
#
# Start of epoch 62
# Epoch [63/200], step : 0 Loss: 1.1045
# Epoch [63/200], step : 1 Loss: 1.2210
# Epoch [63/200], step : 2 Loss: 1.2438
# Epoch [63/200], step : 3 Loss: 1.0699
#
# Start of epoch 63
# Epoch [64/200], step : 0 Loss: 1.1735
# Epoch [64/200], step : 1 Loss: 1.3247
# Epoch [64/200], step : 2 Loss: 1.0217
# Epoch [64/200], step : 3 Loss: 0.9802
#
# Start of epoch 64
# Epoch [65/200], step : 0 Loss: 1.4307
# Epoch [65/200], step : 1 Loss: 1.0678
# Epoch [65/200], step : 2 Loss: 0.9324
# Epoch [65/200], step : 3 Loss: 1.0688
#
# Start of epoch 65
# Epoch [66/200], step : 0 Loss: 1.2555
# Epoch [66/200], step : 1 Loss: 1.0468
# Epoch [66/200], step : 2 Loss: 1.1090
# Epoch [66/200], step : 3 Loss: 0.8826
#
# Start of epoch 66
# Epoch [67/200], step : 0 Loss: 1.1225
# Epoch [67/200], step : 1 Loss: 1.1620
# Epoch [67/200], step : 2 Loss: 1.0859
# Epoch [67/200], step : 3 Loss: 0.7854
#
# Start of epoch 67
# Epoch [68/200], step : 0 Loss: 1.1570
# Epoch [68/200], step : 1 Loss: 1.0505
# Epoch [68/200], step : 2 Loss: 1.1378
# Epoch [68/200], step : 3 Loss: 0.6124
#
# Start of epoch 68
# Epoch [69/200], step : 0 Loss: 1.0700
# Epoch [69/200], step : 1 Loss: 1.1310
# Epoch [69/200], step : 2 Loss: 0.9931
# Epoch [69/200], step : 3 Loss: 0.9503
#
# Start of epoch 69
# Epoch [70/200], step : 0 Loss: 0.9892
# Epoch [70/200], step : 1 Loss: 1.0866
# Epoch [70/200], step : 2 Loss: 1.0593
# Epoch [70/200], step : 3 Loss: 0.9316
#
# Start of epoch 70
# Epoch [71/200], step : 0 Loss: 1.0690
# Epoch [71/200], step : 1 Loss: 0.9174
# Epoch [71/200], step : 2 Loss: 1.0265
# Epoch [71/200], step : 3 Loss: 1.1618
#
# Start of epoch 71
# Epoch [72/200], step : 0 Loss: 0.9348
# Epoch [72/200], step : 1 Loss: 0.9913
# Epoch [72/200], step : 2 Loss: 1.0138
# Epoch [72/200], step : 3 Loss: 1.1921
#
# Start of epoch 72
# Epoch [73/200], step : 0 Loss: 1.0395
# Epoch [73/200], step : 1 Loss: 1.0380
# Epoch [73/200], step : 2 Loss: 0.8937
# Epoch [73/200], step : 3 Loss: 0.8180
#
# Start of epoch 73
# Epoch [74/200], step : 0 Loss: 1.1274
# Epoch [74/200], step : 1 Loss: 1.0104
# Epoch [74/200], step : 2 Loss: 0.8820
# Epoch [74/200], step : 3 Loss: 0.3791
#
# Start of epoch 74
# Epoch [75/200], step : 0 Loss: 0.8505
# Epoch [75/200], step : 1 Loss: 0.9960
# Epoch [75/200], step : 2 Loss: 1.0466
# Epoch [75/200], step : 3 Loss: 0.6297
#
# Start of epoch 75
# Epoch [76/200], step : 0 Loss: 1.0762
# Epoch [76/200], step : 1 Loss: 0.8609
# Epoch [76/200], step : 2 Loss: 0.9050
# Epoch [76/200], step : 3 Loss: 0.5912
#
# Start of epoch 76
# Epoch [77/200], step : 0 Loss: 0.8018
# Epoch [77/200], step : 1 Loss: 0.9879
# Epoch [77/200], step : 2 Loss: 0.8666
# Epoch [77/200], step : 3 Loss: 1.0891
#
# Start of epoch 77
# Epoch [78/200], step : 0 Loss: 0.8593
# Epoch [78/200], step : 1 Loss: 0.9894
# Epoch [78/200], step : 2 Loss: 0.9149
# Epoch [78/200], step : 3 Loss: 0.4255
#
# Start of epoch 78
# Epoch [79/200], step : 0 Loss: 0.7677
# Epoch [79/200], step : 1 Loss: 1.0593
# Epoch [79/200], step : 2 Loss: 0.8062
# Epoch [79/200], step : 3 Loss: 0.7096
#
# Start of epoch 79
# Epoch [80/200], step : 0 Loss: 0.8914
# Epoch [80/200], step : 1 Loss: 0.7541
# Epoch [80/200], step : 2 Loss: 0.9000
# Epoch [80/200], step : 3 Loss: 0.8296
#
# Start of epoch 80
# Epoch [81/200], step : 0 Loss: 0.7988
# Epoch [81/200], step : 1 Loss: 0.9242
# Epoch [81/200], step : 2 Loss: 0.7890
# Epoch [81/200], step : 3 Loss: 0.7187
#
# Start of epoch 81
# Epoch [82/200], step : 0 Loss: 1.0093
# Epoch [82/200], step : 1 Loss: 0.7340
# Epoch [82/200], step : 2 Loss: 0.7479
# Epoch [82/200], step : 3 Loss: 0.5858
#
# Start of epoch 82
# Epoch [83/200], step : 0 Loss: 0.8454
# Epoch [83/200], step : 1 Loss: 0.8207
# Epoch [83/200], step : 2 Loss: 0.7626
# Epoch [83/200], step : 3 Loss: 0.6108
#
# Start of epoch 83
# Epoch [84/200], step : 0 Loss: 0.8368
# Epoch [84/200], step : 1 Loss: 0.5998
# Epoch [84/200], step : 2 Loss: 0.8294
# Epoch [84/200], step : 3 Loss: 1.0202
#
# Start of epoch 84
# Epoch [85/200], step : 0 Loss: 0.5709
# Epoch [85/200], step : 1 Loss: 0.7661
# Epoch [85/200], step : 2 Loss: 0.8311
# Epoch [85/200], step : 3 Loss: 1.1769
#
# Start of epoch 85
# Epoch [86/200], step : 0 Loss: 0.7638
# Epoch [86/200], step : 1 Loss: 0.6506
# Epoch [86/200], step : 2 Loss: 0.6906
# Epoch [86/200], step : 3 Loss: 1.2147
#
# Start of epoch 86
# Epoch [87/200], step : 0 Loss: 0.5950
# Epoch [87/200], step : 1 Loss: 0.9036
# Epoch [87/200], step : 2 Loss: 0.7379
# Epoch [87/200], step : 3 Loss: 0.4525
#
# Start of epoch 87
# Epoch [88/200], step : 0 Loss: 0.7152
# Epoch [88/200], step : 1 Loss: 0.7642
# Epoch [88/200], step : 2 Loss: 0.5600
# Epoch [88/200], step : 3 Loss: 1.0231
#
# Start of epoch 88
# Epoch [89/200], step : 0 Loss: 0.7553
# Epoch [89/200], step : 1 Loss: 0.6541
# Epoch [89/200], step : 2 Loss: 0.5940
# Epoch [89/200], step : 3 Loss: 0.9628
#
# Start of epoch 89
# Epoch [90/200], step : 0 Loss: 0.5865
# Epoch [90/200], step : 1 Loss: 0.5974
# Epoch [90/200], step : 2 Loss: 0.6770
# Epoch [90/200], step : 3 Loss: 1.3000
#
# Start of epoch 90
# Epoch [91/200], step : 0 Loss: 0.5674
# Epoch [91/200], step : 1 Loss: 0.6826
# Epoch [91/200], step : 2 Loss: 0.6770
# Epoch [91/200], step : 3 Loss: 0.8260
#
# Start of epoch 91
# Epoch [92/200], step : 0 Loss: 0.4920
# Epoch [92/200], step : 1 Loss: 0.6895
# Epoch [92/200], step : 2 Loss: 0.7978
# Epoch [92/200], step : 3 Loss: 0.4151
#
# Start of epoch 92
# Epoch [93/200], step : 0 Loss: 0.6601
# Epoch [93/200], step : 1 Loss: 0.3695
# Epoch [93/200], step : 2 Loss: 0.7801
# Epoch [93/200], step : 3 Loss: 0.9033
#
# Start of epoch 93
# Epoch [94/200], step : 0 Loss: 0.7382
# Epoch [94/200], step : 1 Loss: 0.5387
# Epoch [94/200], step : 2 Loss: 0.4864
# Epoch [94/200], step : 3 Loss: 0.9130
#
# Start of epoch 94
# Epoch [95/200], step : 0 Loss: 0.4085
# Epoch [95/200], step : 1 Loss: 0.6282
# Epoch [95/200], step : 2 Loss: 0.7608
# Epoch [95/200], step : 3 Loss: 0.6034
#
# Start of epoch 95
# Epoch [96/200], step : 0 Loss: 0.5955
# Epoch [96/200], step : 1 Loss: 0.5909
# Epoch [96/200], step : 2 Loss: 0.5196
# Epoch [96/200], step : 3 Loss: 0.7881
#
# Start of epoch 96
# Epoch [97/200], step : 0 Loss: 0.5462
# Epoch [97/200], step : 1 Loss: 0.5045
# Epoch [97/200], step : 2 Loss: 0.5968
# Epoch [97/200], step : 3 Loss: 0.8422
#
# Start of epoch 97
# Epoch [98/200], step : 0 Loss: 0.5673
# Epoch [98/200], step : 1 Loss: 0.4727
# Epoch [98/200], step : 2 Loss: 0.5681
# Epoch [98/200], step : 3 Loss: 0.8184
#
# Start of epoch 98
# Epoch [99/200], step : 0 Loss: 0.4991
# Epoch [99/200], step : 1 Loss: 0.6879
# Epoch [99/200], step : 2 Loss: 0.4395
# Epoch [99/200], step : 3 Loss: 0.5600
#
# Start of epoch 99
# Epoch [100/200], step : 0 Loss: 0.6687
# Epoch [100/200], step : 1 Loss: 0.3834
# Epoch [100/200], step : 2 Loss: 0.5553
# Epoch [100/200], step : 3 Loss: 0.4633
#
# Start of epoch 100
# Epoch [101/200], step : 0 Loss: 0.6577
# Epoch [101/200], step : 1 Loss: 0.3879
# Epoch [101/200], step : 2 Loss: 0.4869
# Epoch [101/200], step : 3 Loss: 0.5905
#
# Start of epoch 101
# Epoch [102/200], step : 0 Loss: 0.4887
# Epoch [102/200], step : 1 Loss: 0.5290
# Epoch [102/200], step : 2 Loss: 0.3883
# Epoch [102/200], step : 3 Loss: 0.9294
#
# Start of epoch 102
# Epoch [103/200], step : 0 Loss: 0.4776
# Epoch [103/200], step : 1 Loss: 0.4641
# Epoch [103/200], step : 2 Loss: 0.5375
# Epoch [103/200], step : 3 Loss: 0.4676
#
# Start of epoch 103
# Epoch [104/200], step : 0 Loss: 0.5531
# Epoch [104/200], step : 1 Loss: 0.4883
# Epoch [104/200], step : 2 Loss: 0.4127
# Epoch [104/200], step : 3 Loss: 0.4260
#
# Start of epoch 104
# Epoch [105/200], step : 0 Loss: 0.5066
# Epoch [105/200], step : 1 Loss: 0.4353
# Epoch [105/200], step : 2 Loss: 0.4054
# Epoch [105/200], step : 3 Loss: 0.6883
#
# Start of epoch 105
# Epoch [106/200], step : 0 Loss: 0.5683
# Epoch [106/200], step : 1 Loss: 0.3024
# Epoch [106/200], step : 2 Loss: 0.4438
# Epoch [106/200], step : 3 Loss: 0.6852
#
# Start of epoch 106
# Epoch [107/200], step : 0 Loss: 0.4397
# Epoch [107/200], step : 1 Loss: 0.3190
# Epoch [107/200], step : 2 Loss: 0.5990
# Epoch [107/200], step : 3 Loss: 0.3585
#
# Start of epoch 107
# Epoch [108/200], step : 0 Loss: 0.3968
# Epoch [108/200], step : 1 Loss: 0.3790
# Epoch [108/200], step : 2 Loss: 0.5349
# Epoch [108/200], step : 3 Loss: 0.4068
#
# Start of epoch 108
# Epoch [109/200], step : 0 Loss: 0.5063
# Epoch [109/200], step : 1 Loss: 0.4182
# Epoch [109/200], step : 2 Loss: 0.3774
# Epoch [109/200], step : 3 Loss: 0.3071
#
# Start of epoch 109
# Epoch [110/200], step : 0 Loss: 0.4427
# Epoch [110/200], step : 1 Loss: 0.5044
# Epoch [110/200], step : 2 Loss: 0.3003
# Epoch [110/200], step : 3 Loss: 0.3840
#
# Start of epoch 110
# Epoch [111/200], step : 0 Loss: 0.5210
# Epoch [111/200], step : 1 Loss: 0.3550
# Epoch [111/200], step : 2 Loss: 0.3469
# Epoch [111/200], step : 3 Loss: 0.3560
#
# Start of epoch 111
# Epoch [112/200], step : 0 Loss: 0.3781
# Epoch [112/200], step : 1 Loss: 0.4111
# Epoch [112/200], step : 2 Loss: 0.4123
# Epoch [112/200], step : 3 Loss: 0.3070
#
# Start of epoch 112
# Epoch [113/200], step : 0 Loss: 0.2232
# Epoch [113/200], step : 1 Loss: 0.3953
# Epoch [113/200], step : 2 Loss: 0.4681
# Epoch [113/200], step : 3 Loss: 0.6530
#
# Start of epoch 113
# Epoch [114/200], step : 0 Loss: 0.3920
# Epoch [114/200], step : 1 Loss: 0.3883
# Epoch [114/200], step : 2 Loss: 0.3751
# Epoch [114/200], step : 3 Loss: 0.2662
#
# Start of epoch 114
# Epoch [115/200], step : 0 Loss: 0.4576
# Epoch [115/200], step : 1 Loss: 0.3473
# Epoch [115/200], step : 2 Loss: 0.3324
# Epoch [115/200], step : 3 Loss: 0.2128
#
# Start of epoch 115
# Epoch [116/200], step : 0 Loss: 0.2952
# Epoch [116/200], step : 1 Loss: 0.3299
# Epoch [116/200], step : 2 Loss: 0.4620
# Epoch [116/200], step : 3 Loss: 0.2965
#
# Start of epoch 116
# Epoch [117/200], step : 0 Loss: 0.4456
# Epoch [117/200], step : 1 Loss: 0.3812
# Epoch [117/200], step : 2 Loss: 0.2393
# Epoch [117/200], step : 3 Loss: 0.2711
#
# Start of epoch 117
# Epoch [118/200], step : 0 Loss: 0.3665
# Epoch [118/200], step : 1 Loss: 0.2460
# Epoch [118/200], step : 2 Loss: 0.3561
# Epoch [118/200], step : 3 Loss: 0.5560
#
# Start of epoch 118
# Epoch [119/200], step : 0 Loss: 0.3823
# Epoch [119/200], step : 1 Loss: 0.3001
# Epoch [119/200], step : 2 Loss: 0.3536
# Epoch [119/200], step : 3 Loss: 0.1870
#
# Start of epoch 119
# Epoch [120/200], step : 0 Loss: 0.3771
# Epoch [120/200], step : 1 Loss: 0.3002
# Epoch [120/200], step : 2 Loss: 0.2541
# Epoch [120/200], step : 3 Loss: 0.5009
#
# Start of epoch 120
# Epoch [121/200], step : 0 Loss: 0.3042
# Epoch [121/200], step : 1 Loss: 0.2765
# Epoch [121/200], step : 2 Loss: 0.4085
# Epoch [121/200], step : 3 Loss: 0.1700
#
# Start of epoch 121
# Epoch [122/200], step : 0 Loss: 0.3153
# Epoch [122/200], step : 1 Loss: 0.3019
# Epoch [122/200], step : 2 Loss: 0.3017
# Epoch [122/200], step : 3 Loss: 0.3421
#
# Start of epoch 122
# Epoch [123/200], step : 0 Loss: 0.3110
# Epoch [123/200], step : 1 Loss: 0.3234
# Epoch [123/200], step : 2 Loss: 0.3082
# Epoch [123/200], step : 3 Loss: 0.1475
#
# Start of epoch 123
# Epoch [124/200], step : 0 Loss: 0.2097
# Epoch [124/200], step : 1 Loss: 0.2793
# Epoch [124/200], step : 2 Loss: 0.4102
# Epoch [124/200], step : 3 Loss: 0.2307
#
# Start of epoch 124
# Epoch [125/200], step : 0 Loss: 0.2023
# Epoch [125/200], step : 1 Loss: 0.3208
# Epoch [125/200], step : 2 Loss: 0.3729
# Epoch [125/200], step : 3 Loss: 0.1672
#
# Start of epoch 125
# Epoch [126/200], step : 0 Loss: 0.2504
# Epoch [126/200], step : 1 Loss: 0.1818
# Epoch [126/200], step : 2 Loss: 0.3874
# Epoch [126/200], step : 3 Loss: 0.3880
#
# Start of epoch 126
# Epoch [127/200], step : 0 Loss: 0.2145
# Epoch [127/200], step : 1 Loss: 0.3302
# Epoch [127/200], step : 2 Loss: 0.2497
# Epoch [127/200], step : 3 Loss: 0.3967
#
# Start of epoch 127
# Epoch [128/200], step : 0 Loss: 0.2036
# Epoch [128/200], step : 1 Loss: 0.1668
# Epoch [128/200], step : 2 Loss: 0.4533
# Epoch [128/200], step : 3 Loss: 0.1918
#
# Start of epoch 128
# Epoch [129/200], step : 0 Loss: 0.2817
# Epoch [129/200], step : 1 Loss: 0.2790
# Epoch [129/200], step : 2 Loss: 0.2047
# Epoch [129/200], step : 3 Loss: 0.3511
#
# Start of epoch 129
# Epoch [130/200], step : 0 Loss: 0.3542
# Epoch [130/200], step : 1 Loss: 0.1905
# Epoch [130/200], step : 2 Loss: 0.2628
# Epoch [130/200], step : 3 Loss: 0.0940
#
# Start of epoch 130
# Epoch [131/200], step : 0 Loss: 0.2025
# Epoch [131/200], step : 1 Loss: 0.2772
# Epoch [131/200], step : 2 Loss: 0.2971
# Epoch [131/200], step : 3 Loss: 0.1350
#
# Start of epoch 131
# Epoch [132/200], step : 0 Loss: 0.2963
# Epoch [132/200], step : 1 Loss: 0.2502
# Epoch [132/200], step : 2 Loss: 0.1919
# Epoch [132/200], step : 3 Loss: 0.2131
#
# Start of epoch 132
# Epoch [133/200], step : 0 Loss: 0.2045
# Epoch [133/200], step : 1 Loss: 0.1811
# Epoch [133/200], step : 2 Loss: 0.2785
# Epoch [133/200], step : 3 Loss: 0.4331
#
# Start of epoch 133
# Epoch [134/200], step : 0 Loss: 0.2000
# Epoch [134/200], step : 1 Loss: 0.2950
# Epoch [134/200], step : 2 Loss: 0.1643
# Epoch [134/200], step : 3 Loss: 0.3746
#
# Start of epoch 134
# Epoch [135/200], step : 0 Loss: 0.1608
# Epoch [135/200], step : 1 Loss: 0.2037
# Epoch [135/200], step : 2 Loss: 0.2892
# Epoch [135/200], step : 3 Loss: 0.3171
#
# Start of epoch 135
# Epoch [136/200], step : 0 Loss: 0.2252
# Epoch [136/200], step : 1 Loss: 0.2360
# Epoch [136/200], step : 2 Loss: 0.1568
# Epoch [136/200], step : 3 Loss: 0.3891
#
# Start of epoch 136
# Epoch [137/200], step : 0 Loss: 0.2446
# Epoch [137/200], step : 1 Loss: 0.2117
# Epoch [137/200], step : 2 Loss: 0.1856
# Epoch [137/200], step : 3 Loss: 0.2264
#
# Start of epoch 137
# Epoch [138/200], step : 0 Loss: 0.2211
# Epoch [138/200], step : 1 Loss: 0.2459
# Epoch [138/200], step : 2 Loss: 0.1443
# Epoch [138/200], step : 3 Loss: 0.2763
#
# Start of epoch 138
# Epoch [139/200], step : 0 Loss: 0.1268
# Epoch [139/200], step : 1 Loss: 0.2011
# Epoch [139/200], step : 2 Loss: 0.2300
# Epoch [139/200], step : 3 Loss: 0.4120
#
# Start of epoch 139
# Epoch [140/200], step : 0 Loss: 0.2086
# Epoch [140/200], step : 1 Loss: 0.1884
# Epoch [140/200], step : 2 Loss: 0.1738
# Epoch [140/200], step : 3 Loss: 0.2953
#
# Start of epoch 140
# Epoch [141/200], step : 0 Loss: 0.1106
# Epoch [141/200], step : 1 Loss: 0.2853
# Epoch [141/200], step : 2 Loss: 0.1489
# Epoch [141/200], step : 3 Loss: 0.3224
#
# Start of epoch 141
# Epoch [142/200], step : 0 Loss: 0.2010
# Epoch [142/200], step : 1 Loss: 0.2123
# Epoch [142/200], step : 2 Loss: 0.1686
# Epoch [142/200], step : 3 Loss: 0.1150
#
# Start of epoch 142
# Epoch [143/200], step : 0 Loss: 0.2331
# Epoch [143/200], step : 1 Loss: 0.1017
# Epoch [143/200], step : 2 Loss: 0.1837
# Epoch [143/200], step : 3 Loss: 0.3037
#
# Start of epoch 143
# Epoch [144/200], step : 0 Loss: 0.1607
# Epoch [144/200], step : 1 Loss: 0.2664
# Epoch [144/200], step : 2 Loss: 0.1309
# Epoch [144/200], step : 3 Loss: 0.0779
#
# Start of epoch 144
# Epoch [145/200], step : 0 Loss: 0.1711
# Epoch [145/200], step : 1 Loss: 0.2189
# Epoch [145/200], step : 2 Loss: 0.1340
# Epoch [145/200], step : 3 Loss: 0.1470
#
# Start of epoch 145
# Epoch [146/200], step : 0 Loss: 0.1555
# Epoch [146/200], step : 1 Loss: 0.1416
# Epoch [146/200], step : 2 Loss: 0.2032
# Epoch [146/200], step : 3 Loss: 0.1878
#
# Start of epoch 146
# Epoch [147/200], step : 0 Loss: 0.2163
# Epoch [147/200], step : 1 Loss: 0.1251
# Epoch [147/200], step : 2 Loss: 0.1793
# Epoch [147/200], step : 3 Loss: 0.0514
#
# Start of epoch 147
# Epoch [148/200], step : 0 Loss: 0.1231
# Epoch [148/200], step : 1 Loss: 0.1662
# Epoch [148/200], step : 2 Loss: 0.1739
# Epoch [148/200], step : 3 Loss: 0.2279
#
# Start of epoch 148
# Epoch [149/200], step : 0 Loss: 0.1374
# Epoch [149/200], step : 1 Loss: 0.1768
# Epoch [149/200], step : 2 Loss: 0.1695
# Epoch [149/200], step : 3 Loss: 0.0998
#
# Start of epoch 149
# Epoch [150/200], step : 0 Loss: 0.1616
# Epoch [150/200], step : 1 Loss: 0.1826
# Epoch [150/200], step : 2 Loss: 0.1284
# Epoch [150/200], step : 3 Loss: 0.0935
#
# Start of epoch 150
# Epoch [151/200], step : 0 Loss: 0.1532
# Epoch [151/200], step : 1 Loss: 0.1455
# Epoch [151/200], step : 2 Loss: 0.1664
# Epoch [151/200], step : 3 Loss: 0.0765
#
# Start of epoch 151
# Epoch [152/200], step : 0 Loss: 0.1650
# Epoch [152/200], step : 1 Loss: 0.1444
# Epoch [152/200], step : 2 Loss: 0.1492
# Epoch [152/200], step : 3 Loss: 0.0564
#
# Start of epoch 152
# Epoch [153/200], step : 0 Loss: 0.1318
# Epoch [153/200], step : 1 Loss: 0.1681
# Epoch [153/200], step : 2 Loss: 0.1336
# Epoch [153/200], step : 3 Loss: 0.1136
#
# Start of epoch 153
# Epoch [154/200], step : 0 Loss: 0.1650
# Epoch [154/200], step : 1 Loss: 0.1561
# Epoch [154/200], step : 2 Loss: 0.1127
# Epoch [154/200], step : 3 Loss: 0.0716
#
# Start of epoch 154
# Epoch [155/200], step : 0 Loss: 0.1185
# Epoch [155/200], step : 1 Loss: 0.1184
# Epoch [155/200], step : 2 Loss: 0.1503
# Epoch [155/200], step : 3 Loss: 0.2197
#
# Start of epoch 155
# Epoch [156/200], step : 0 Loss: 0.1313
# Epoch [156/200], step : 1 Loss: 0.1431
# Epoch [156/200], step : 2 Loss: 0.1112
# Epoch [156/200], step : 3 Loss: 0.1823
#
# Start of epoch 156
# Epoch [157/200], step : 0 Loss: 0.0894
# Epoch [157/200], step : 1 Loss: 0.1252
# Epoch [157/200], step : 2 Loss: 0.1904
# Epoch [157/200], step : 3 Loss: 0.0607
#
# Start of epoch 157
# Epoch [158/200], step : 0 Loss: 0.1526
# Epoch [158/200], step : 1 Loss: 0.1040
# Epoch [158/200], step : 2 Loss: 0.1292
# Epoch [158/200], step : 3 Loss: 0.1009
#
# Start of epoch 158
# Epoch [159/200], step : 0 Loss: 0.1533
# Epoch [159/200], step : 1 Loss: 0.1480
# Epoch [159/200], step : 2 Loss: 0.0559
# Epoch [159/200], step : 3 Loss: 0.1795
#
# Start of epoch 159
# Epoch [160/200], step : 0 Loss: 0.1214
# Epoch [160/200], step : 1 Loss: 0.1507
# Epoch [160/200], step : 2 Loss: 0.0916
# Epoch [160/200], step : 3 Loss: 0.1137
#
# Start of epoch 160
# Epoch [161/200], step : 0 Loss: 0.1521
# Epoch [161/200], step : 1 Loss: 0.1168
# Epoch [161/200], step : 2 Loss: 0.1039
# Epoch [161/200], step : 3 Loss: 0.0403
#
# Start of epoch 161
# Epoch [162/200], step : 0 Loss: 0.0849
# Epoch [162/200], step : 1 Loss: 0.0862
# Epoch [162/200], step : 2 Loss: 0.1767
# Epoch [162/200], step : 3 Loss: 0.1028
#
# Start of epoch 162
# Epoch [163/200], step : 0 Loss: 0.1277
# Epoch [163/200], step : 1 Loss: 0.1136
# Epoch [163/200], step : 2 Loss: 0.1077
# Epoch [163/200], step : 3 Loss: 0.0664
#
# Start of epoch 163
# Epoch [164/200], step : 0 Loss: 0.0746
# Epoch [164/200], step : 1 Loss: 0.1348
# Epoch [164/200], step : 2 Loss: 0.1077
# Epoch [164/200], step : 3 Loss: 0.1579
#
# Start of epoch 164
# Epoch [165/200], step : 0 Loss: 0.0825
# Epoch [165/200], step : 1 Loss: 0.1524
# Epoch [165/200], step : 2 Loss: 0.0809
# Epoch [165/200], step : 3 Loss: 0.1328
#
# Start of epoch 165
# Epoch [166/200], step : 0 Loss: 0.1069
# Epoch [166/200], step : 1 Loss: 0.1422
# Epoch [166/200], step : 2 Loss: 0.0789
# Epoch [166/200], step : 3 Loss: 0.0540
#
# Start of epoch 166
# Epoch [167/200], step : 0 Loss: 0.0797
# Epoch [167/200], step : 1 Loss: 0.1152
# Epoch [167/200], step : 2 Loss: 0.0920
# Epoch [167/200], step : 3 Loss: 0.1857
#
# Start of epoch 167
# Epoch [168/200], step : 0 Loss: 0.1298
# Epoch [168/200], step : 1 Loss: 0.0711
# Epoch [168/200], step : 2 Loss: 0.1069
# Epoch [168/200], step : 3 Loss: 0.0762
#
# Start of epoch 168
# Epoch [169/200], step : 0 Loss: 0.0999
# Epoch [169/200], step : 1 Loss: 0.1065
# Epoch [169/200], step : 2 Loss: 0.1070
# Epoch [169/200], step : 3 Loss: 0.0213
#
# Start of epoch 169
# Epoch [170/200], step : 0 Loss: 0.0863
# Epoch [170/200], step : 1 Loss: 0.0715
# Epoch [170/200], step : 2 Loss: 0.1152
# Epoch [170/200], step : 3 Loss: 0.1534
#
# Start of epoch 170
# Epoch [171/200], step : 0 Loss: 0.1021
# Epoch [171/200], step : 1 Loss: 0.1009
# Epoch [171/200], step : 2 Loss: 0.0779
# Epoch [171/200], step : 3 Loss: 0.0945
#
# Start of epoch 171
# Epoch [172/200], step : 0 Loss: 0.0959
# Epoch [172/200], step : 1 Loss: 0.0931
# Epoch [172/200], step : 2 Loss: 0.0927
# Epoch [172/200], step : 3 Loss: 0.0663
#
# Start of epoch 172
# Epoch [173/200], step : 0 Loss: 0.0997
# Epoch [173/200], step : 1 Loss: 0.0762
# Epoch [173/200], step : 2 Loss: 0.1016
# Epoch [173/200], step : 3 Loss: 0.0547
#
# Start of epoch 173
# Epoch [174/200], step : 0 Loss: 0.0521
# Epoch [174/200], step : 1 Loss: 0.1275
# Epoch [174/200], step : 2 Loss: 0.0908
# Epoch [174/200], step : 3 Loss: 0.0613
#
# Start of epoch 174
# Epoch [175/200], step : 0 Loss: 0.0825
# Epoch [175/200], step : 1 Loss: 0.1059
# Epoch [175/200], step : 2 Loss: 0.0795
# Epoch [175/200], step : 3 Loss: 0.0490
#
# Start of epoch 175
# Epoch [176/200], step : 0 Loss: 0.0577
# Epoch [176/200], step : 1 Loss: 0.0904
# Epoch [176/200], step : 2 Loss: 0.1037
# Epoch [176/200], step : 3 Loss: 0.0919
#
# Start of epoch 176
# Epoch [177/200], step : 0 Loss: 0.0951
# Epoch [177/200], step : 1 Loss: 0.0842
# Epoch [177/200], step : 2 Loss: 0.0578
# Epoch [177/200], step : 3 Loss: 0.1345
#
# Start of epoch 177
# Epoch [178/200], step : 0 Loss: 0.0695
# Epoch [178/200], step : 1 Loss: 0.0858
# Epoch [178/200], step : 2 Loss: 0.0911
# Epoch [178/200], step : 3 Loss: 0.0703
#
# Start of epoch 178
# Epoch [179/200], step : 0 Loss: 0.1176
# Epoch [179/200], step : 1 Loss: 0.0478
# Epoch [179/200], step : 2 Loss: 0.0812
# Epoch [179/200], step : 3 Loss: 0.0487
#
# Start of epoch 179
# Epoch [180/200], step : 0 Loss: 0.1001
# Epoch [180/200], step : 1 Loss: 0.0709
# Epoch [180/200], step : 2 Loss: 0.0616
# Epoch [180/200], step : 3 Loss: 0.0801
#
# Start of epoch 180
# Epoch [181/200], step : 0 Loss: 0.0362
# Epoch [181/200], step : 1 Loss: 0.0812
# Epoch [181/200], step : 2 Loss: 0.0963
# Epoch [181/200], step : 3 Loss: 0.1322
#
# Start of epoch 181
# Epoch [182/200], step : 0 Loss: 0.0573
# Epoch [182/200], step : 1 Loss: 0.0687
# Epoch [182/200], step : 2 Loss: 0.0907
# Epoch [182/200], step : 3 Loss: 0.1005
#
# Start of epoch 182
# Epoch [183/200], step : 0 Loss: 0.1010
# Epoch [183/200], step : 1 Loss: 0.0586
# Epoch [183/200], step : 2 Loss: 0.0582
# Epoch [183/200], step : 3 Loss: 0.0737
#
# Start of epoch 183
# Epoch [184/200], step : 0 Loss: 0.0479
# Epoch [184/200], step : 1 Loss: 0.0474
# Epoch [184/200], step : 2 Loss: 0.1197
# Epoch [184/200], step : 3 Loss: 0.0618
#
# Start of epoch 184
# Epoch [185/200], step : 0 Loss: 0.0752
# Epoch [185/200], step : 1 Loss: 0.0490
# Epoch [185/200], step : 2 Loss: 0.0927
# Epoch [185/200], step : 3 Loss: 0.0351
#
# Start of epoch 185
# Epoch [186/200], step : 0 Loss: 0.0576
# Epoch [186/200], step : 1 Loss: 0.0543
# Epoch [186/200], step : 2 Loss: 0.0920
# Epoch [186/200], step : 3 Loss: 0.0694
#
# Start of epoch 186
# Epoch [187/200], step : 0 Loss: 0.0828
# Epoch [187/200], step : 1 Loss: 0.0646
# Epoch [187/200], step : 2 Loss: 0.0558
# Epoch [187/200], step : 3 Loss: 0.0549
#
# Start of epoch 187
# Epoch [188/200], step : 0 Loss: 0.0813
# Epoch [188/200], step : 1 Loss: 0.0388
# Epoch [188/200], step : 2 Loss: 0.0629
# Epoch [188/200], step : 3 Loss: 0.1187
#
# Start of epoch 188
# Epoch [189/200], step : 0 Loss: 0.0759
# Epoch [189/200], step : 1 Loss: 0.0582
# Epoch [189/200], step : 2 Loss: 0.0714
# Epoch [189/200], step : 3 Loss: 0.0099
#
# Start of epoch 189
# Epoch [190/200], step : 0 Loss: 0.0677
# Epoch [190/200], step : 1 Loss: 0.0901
# Epoch [190/200], step : 2 Loss: 0.0366
# Epoch [190/200], step : 3 Loss: 0.0409
#
# Start of epoch 190
# Epoch [191/200], step : 0 Loss: 0.0582
# Epoch [191/200], step : 1 Loss: 0.0776
# Epoch [191/200], step : 2 Loss: 0.0507
# Epoch [191/200], step : 3 Loss: 0.0580
#
# Start of epoch 191
# Epoch [192/200], step : 0 Loss: 0.0794
# Epoch [192/200], step : 1 Loss: 0.0529
# Epoch [192/200], step : 2 Loss: 0.0574
# Epoch [192/200], step : 3 Loss: 0.0294
#
# Start of epoch 192
# Epoch [193/200], step : 0 Loss: 0.0568
# Epoch [193/200], step : 1 Loss: 0.0571
# Epoch [193/200], step : 2 Loss: 0.0527
# Epoch [193/200], step : 3 Loss: 0.1076
#
# Start of epoch 193
# Epoch [194/200], step : 0 Loss: 0.0665
# Epoch [194/200], step : 1 Loss: 0.0798
# Epoch [194/200], step : 2 Loss: 0.0309
# Epoch [194/200], step : 3 Loss: 0.0504
#
# Start of epoch 194
# Epoch [195/200], step : 0 Loss: 0.0814
# Epoch [195/200], step : 1 Loss: 0.0362
# Epoch [195/200], step : 2 Loss: 0.0586
# Epoch [195/200], step : 3 Loss: 0.0393
#
# Start of epoch 195
# Epoch [196/200], step : 0 Loss: 0.0728
# Epoch [196/200], step : 1 Loss: 0.0406
# Epoch [196/200], step : 2 Loss: 0.0568
# Epoch [196/200], step : 3 Loss: 0.0503
#
# Start of epoch 196
# Epoch [197/200], step : 0 Loss: 0.0462
# Epoch [197/200], step : 1 Loss: 0.0455
# Epoch [197/200], step : 2 Loss: 0.0729
# Epoch [197/200], step : 3 Loss: 0.0569
#
# Start of epoch 197
# Epoch [198/200], step : 0 Loss: 0.0471
# Epoch [198/200], step : 1 Loss: 0.0439
# Epoch [198/200], step : 2 Loss: 0.0697
# Epoch [198/200], step : 3 Loss: 0.0597
#
# Start of epoch 198
# Epoch [199/200], step : 0 Loss: 0.0626
# Epoch [199/200], step : 1 Loss: 0.0532
# Epoch [199/200], step : 2 Loss: 0.0378
# Epoch [199/200], step : 3 Loss: 0.0768
#
# Start of epoch 199
# Epoch [200/200], step : 0 Loss: 0.0594
# Epoch [200/200], step : 1 Loss: 0.0574
# Epoch [200/200], step : 2 Loss: 0.0439
# Epoch [200/200], step : 3 Loss: 0.0348
# final loss: 0.0348

# %% [markdown]
# # Chat-Bot

# %%
with open('../Dataset.json', 'r') as f:
    dataset = json.load(f)

bot_name = "Robot"
print("How may help you! (type 'q' to exit)")
while True:
    sentence = input("You: ")
    if sentence == "q":
        break

    sentence = tokenize(sentence)
    X = bag_of_words(sentence, all_words)
    X = X.reshape(1, X.shape[0])

    output = model.predict(X)
    
    tag = tags[np.argmax(output)]
    #print(tag)
    #print(output[0][np.argmax(output)])
    
    if output[0][np.argmax(output)] > 0.75 :
        for conv in dataset['conversations']:
            if tag == conv["header"]:
                print(f"{bot_name}: {random.choice(conv['responses'])}")
    else:
        print(f"{bot_name}: I do not understand...")
# Out:
# How may help you! (type 'q' to exit)
# You: hi
# Robot: Hey :-)
# You: tell me joke
# Robot: Why did the hipster burn his mouth? He drank the coffee before it was cool.
# You: hello
# Robot: Hi there, what can I do for you?
# You: hiiii
# Robot: I do not understand...
# You: heloo
# Robot: I do not understand...
# You: qwertyuiop
# Robot: I do not understand...
# You: q
